# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

from sklearn.metrics import confusion_matrix, ConfusionMatrixDisplay
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import LabelEncoder, MinMaxScaler

from keras.callbacks import EarlyStopping, ReduceLROnPlateau
from keras.models import Sequential
from keras.layers import Dense, Dropout

# %%
train_set = pd.read_csv("./Data/train.csv")
test_set = pd.read_csv("./Data/test.csv")

# %%
train_set.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %% [markdown]
# # Explorative Data Analysis

# %%
unique_ticket_values = train_set["Ticket"].nunique()
unique_fare_values = train_set["Fare"].nunique()
unique_cabin_values = train_set["Cabin"].nunique()
unique_embarked_values = train_set["Embarked"].nunique()

print(f"Unique Ticket Values: {unique_ticket_values}")
print(f"Unique Fare Values: {unique_fare_values}")
print(f"Unique Cabin Values: {unique_cabin_values}")
print(f"Unique Embarked Values: {unique_embarked_values}")
# Out:
# Unique Ticket Values: 681
# Unique Fare Values: 248
# Unique Cabin Values: 147
# Unique Embarked Values: 3

# %%
# Test whether names from train occur in test --> only 2 occurences so the Name column will be neglected
multiple_name_occurences = pd.merge(train_set, test_set, how="inner", on="Name")
multiple_name_occurences.head()
# Out:
#    PassengerId_x  Survived  Pclass_x                  Name   Sex_x  Age_x  \
# 0            290         1         3  Connolly, Miss. Kate  female   22.0
# 1            697         0         3      Kelly, Mr. James    male   44.0
#
#    SibSp_x  Parch_x Ticket_x  Fare_x  ... PassengerId_y Pclass_y   Sex_y  \
# 0        0        0   370373    7.75  ...           898        3  female
# 1        0        0   363592    8.05  ...           892        3    male
#
#    Age_y SibSp_y  Parch_y  Ticket_y  Fare_y Cabin_y  Embarked_y
# 0   30.0       0        0    330972  7.6292     NaN           Q
# 1   34.5       0        0    330911  7.8292     NaN           Q
#
# [2 rows x 22 columns]

# %%
# This code plots columns in a dataframe.

# Interesting Columns
columns_to_visualize = ["Survived", "Pclass", "Sex", "SibSp", "Parch", "Embarked"]

# The number of rows, columns, and the subplot counter are initialized. 
a = len(columns_to_visualize)  # number of rows
b = 1  # number of columns
c = 1  # initialize plot counter

colors = plt.rcParams["axes.prop_cycle"]()
# A figure is initialized 
fig = plt.figure(figsize=(12,15))

for i in range(len(columns_to_visualize)):
    value_counts = train_set[columns_to_visualize[i]].value_counts()
    color = next(colors)["color"]
    plt.subplot(a, b, c)
    #Plotting the line for each column in a different color
    value_counts.plot(kind="bar")
    # plt.bar(value_counts, color = color)
    # The spines of each plot are made invisible and the figure is adjusted and shown.
    plt.gca().spines['top'].set_visible(False)
    plt.gca().spines['right'].set_visible(False)
    #Adding Title
    plt.title(columns_to_visualize[i], fontsize=16)
    plt.xlabel('Occurences')
    #Adding y axis label
    plt.ylabel(columns_to_visualize[i])
    #Adding Legend
    plt.legend([columns_to_visualize[i]])
    #Plot Counter value is increased by one after each iteration
    c = c + 1

#Layout is tightended up
plt.tight_layout()

#plot is displayed
plt.show()

# %% [markdown]
# # Data Preprocessing

# %%
labels = train_set["Survived"]
train_set_cleaned = train_set[["Pclass", "Sex", "Age", "SibSp", "Parch", "Ticket", "Fare", "Cabin", "Embarked"]]
train_set_cleaned.head()
# Out:
#    Pclass     Sex   Age  SibSp  Parch            Ticket     Fare Cabin  \
# 0       3    male  22.0      1      0         A/5 21171   7.2500   NaN
# 1       1  female  38.0      1      0          PC 17599  71.2833   C85
# 2       3  female  26.0      0      0  STON/O2. 3101282   7.9250   NaN
# 3       1  female  35.0      1      0            113803  53.1000  C123
# 4       3    male  35.0      0      0            373450   8.0500   NaN
#
#   Embarked
# 0        S
# 1        C
# 2        S
# 3        S
# 4        S

# %%
train_set_cleaned = train_set_cleaned.fillna(0)
train_set_cleaned["Cabin"] = train_set_cleaned["Cabin"].astype(str)
train_set_cleaned["Embarked"] = train_set_cleaned["Embarked"].astype(str)
train_set_cleaned.head()
# Out:
#    Pclass     Sex   Age  SibSp  Parch            Ticket     Fare Cabin  \
# 0       3    male  22.0      1      0         A/5 21171   7.2500     0
# 1       1  female  38.0      1      0          PC 17599  71.2833   C85
# 2       3  female  26.0      0      0  STON/O2. 3101282   7.9250     0
# 3       1  female  35.0      1      0            113803  53.1000  C123
# 4       3    male  35.0      0      0            373450   8.0500     0
#
#   Embarked
# 0        S
# 1        C
# 2        S
# 3        S
# 4        S

# %%
train_set_cleaned.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 9 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Pclass    891 non-null    int64
#  1   Sex       891 non-null    object
#  2   Age       891 non-null    float64
#  3   SibSp     891 non-null    int64
#  4   Parch     891 non-null    int64
#  5   Ticket    891 non-null    object
#  6   Fare      891 non-null    float64
#  7   Cabin     891 non-null    object
#  8   Embarked  891 non-null    object
# dtypes: float64(2), int64(3), object(4)
# memory usage: 62.8+ KB

# %%
for column in train_set_cleaned.columns:
    encoder = LabelEncoder()
    train_set_cleaned[column] = encoder.fit_transform(train_set_cleaned[column])
train_set_cleaned.head()
# Out:
#    Pclass  Sex  Age  SibSp  Parch  Ticket  Fare  Cabin  Embarked
# 0       2    1   29      1      0     523    18      0         3
# 1       0    0   52      1      0     596   207     82         1
# 2       2    0   35      0      0     669    41      0         3
# 3       0    0   48      1      0      49   189     56         3
# 4       2    1   48      0      0     472    43      0         3

# %%
for column in train_set_cleaned.columns:
    scaler = MinMaxScaler()
    reshaped_column = np.array(train_set_cleaned[column]).reshape(-1, 1)
    train_set_cleaned[column] = scaler.fit_transform(reshaped_column)
train_set_cleaned.head()
# Out:
#    Pclass  Sex       Age     SibSp  Parch    Ticket      Fare     Cabin  \
# 0     1.0  1.0  0.329545  0.166667    0.0  0.769118  0.072874  0.000000
# 1     0.0  0.0  0.590909  0.166667    0.0  0.876471  0.838057  0.557823
# 2     1.0  0.0  0.397727  0.000000    0.0  0.983824  0.165992  0.000000
# 3     0.0  0.0  0.545455  0.166667    0.0  0.072059  0.765182  0.380952
# 4     1.0  1.0  0.545455  0.000000    0.0  0.694118  0.174089  0.000000
#
#    Embarked
# 0  1.000000
# 1  0.333333
# 2  1.000000
# 3  1.000000
# 4  1.000000

# %%
X_train, X_val, y_train, y_val = train_test_split(train_set_cleaned, labels, test_size=0.2, random_state=42)

# %% [markdown]
# # Modeling

# %%
dropout_rate = 0.2
model = Sequential()

model.add(Dense(X_train.shape[1], activation="relu"))
model.add(Dropout(dropout_rate))

model.add(Dense(16, activation="relu"))
model.add(Dropout(dropout_rate))

model.add(Dense(32, activation="relu"))
model.add(Dropout(dropout_rate))

model.add(Dense(16, activation="relu"))
model.add(Dropout(dropout_rate))

model.add(Dense(1, activation="sigmoid"))

# %%
early_stop = EarlyStopping(patience=20, restore_best_weights=True)
reduce_lr = ReduceLROnPlateau(patience=10, factor=0.1)

model.compile(optimizer="adam", loss="binary_crossentropy", metrics=["accuracy"])
history = model.fit(X_train, y_train, batch_size=32, epochs=100, callbacks=[early_stop, reduce_lr], validation_split=0.2)
# Out:
# Epoch 1/100
# 18/18 [==============================] - 1s 21ms/step - loss: 0.6860 - accuracy: 0.5606 - val_loss: 0.6741 - val_accuracy: 0.6503 - lr: 0.0010
# Epoch 2/100
# 18/18 [==============================] - 0s 5ms/step - loss: 0.6761 - accuracy: 0.5975 - val_loss: 0.6565 - val_accuracy: 0.6503 - lr: 0.0010
# Epoch 3/100
# 18/18 [==============================] - 0s 6ms/step - loss: 0.6772 - accuracy: 0.6151 - val_loss: 0.6474 - val_accuracy: 0.6503 - lr: 0.0010
# Epoch 4/100
# 18/18 [==============================] - 0s 5ms/step - loss: 0.6659 - accuracy: 0.6134 - val_loss: 0.6423 - val_accuracy: 0.6503 - lr: 0.0010
# Epoch 5/100
# 18/18 [==============================] - 0s 5ms/step - loss: 0.6633 - accuracy: 0.6169 - val_loss: 0.6333 - val_accuracy: 0.6503 - lr: 0.0010
# Epoch 6/100
# 18/18 [==============================] - 0s 5ms/step - loss: 0.6567 - accuracy: 0.6151 - val_loss: 0.6244 - val_accuracy: 0.6503 - lr: 0.0010
# Epoch 7/100
# 18/18 [==============================] - 0s 5ms/step - loss: 0.6564 - accuracy: 0.6151 - val_loss: 0.6143 - val_accuracy: 0.6503 - lr: 0.0010
# Epoch 8/100
# 18/18 [==============================] - 0s 5ms/step - loss: 0.6540 - accuracy: 0.6098 - val_loss: 0.6055 - val_accuracy: 0.6643 - lr: 0.0010
# Epoch 9/100
# 18/18 [==============================] - 0s 5ms/step - loss: 0.6473 - accuracy: 0.6134 - val_loss: 0.5891 - val_accuracy: 0.6643 - lr: 0.0010
# Epoch 10/100
# 18/18 [==============================] - 0s 6ms/step - loss: 0.6406 - accuracy: 0.6503 - val_loss: 0.5762 - val_accuracy: 0.7273 - lr: 0.0010
# Epoch 11/100
# 18/18 [==============================] - 0s 5ms/step - loss: 0.6231 - accuracy: 0.6555 - val_loss: 0.5586 - val_accuracy: 0.7552 - lr: 0.0010
# Epoch 12/100
# 18/18 [==============================] - 0s 5ms/step - loss: 0.6049 - accuracy: 0.6907 - val_loss: 0.5365 - val_accuracy: 0.7692 - lr: 0.0010
# Epoch 13/100
# 18/18 [==============================] - 0s 5ms/step - loss: 0.5868 - accuracy: 0.7118 - val_loss: 0.5066 - val_accuracy: 0.7972 - lr: 0.0010
# Epoch 14/100
# 18/18 [==============================] - 0s 5ms/step - loss: 0.5735 - accuracy: 0.7135 - val_loss: 0.4893 - val_accuracy: 0.7832 - lr: 0.0010
# Epoch 15/100
# 18/18 [==============================] - 0s 5ms/step - loss: 0.5620 - accuracy: 0.7206 - val_loss: 0.4746 - val_accuracy: 0.7832 - lr: 0.0010
# Epoch 16/100
# 18/18 [==============================] - 0s 6ms/step - loss: 0.5484 - accuracy: 0.7434 - val_loss: 0.4717 - val_accuracy: 0.7902 - lr: 0.0010
# Epoch 17/100
# 18/18 [==============================] - 0s 5ms/step - loss: 0.5604 - accuracy: 0.7364 - val_loss: 0.4676 - val_accuracy: 0.7972 - lr: 0.0010
# Epoch 18/100
# 18/18 [==============================] - 0s 6ms/step - loss: 0.5713 - accuracy: 0.7469 - val_loss: 0.4698 - val_accuracy: 0.7972 - lr: 0.0010
# Epoch 19/100
# 18/18 [==============================] - 0s 6ms/step - loss: 0.5426 - accuracy: 0.7627 - val_loss: 0.4678 - val_accuracy: 0.8182 - lr: 0.0010
# Epoch 20/100
# 18/18 [==============================] - 0s 6ms/step - loss: 0.5341 - accuracy: 0.7610 - val_loss: 0.4629 - val_accuracy: 0.8112 - lr: 0.0010
# Epoch 21/100
# 18/18 [==============================] - 0s 6ms/step - loss: 0.5125 - accuracy: 0.7680 - val_loss: 0.4552 - val_accuracy: 0.8182 - lr: 0.0010
# Epoch 22/100
# 18/18 [==============================] - 0s 5ms/step - loss: 0.5501 - accuracy: 0.7540 - val_loss: 0.4563 - val_accuracy: 0.8182 - lr: 0.0010
# Epoch 23/100
# 18/18 [==============================] - 0s 6ms/step - loss: 0.5189 - accuracy: 0.7715 - val_loss: 0.4501 - val_accuracy: 0.8112 - lr: 0.0010
# Epoch 24/100
# 18/18 [==============================] - 0s 5ms/step - loss: 0.5328 - accuracy: 0.7610 - val_loss: 0.4490 - val_accuracy: 0.8322 - lr: 0.0010
# Epoch 25/100
# 18/18 [==============================] - 0s 5ms/step - loss: 0.5200 - accuracy: 0.7592 - val_loss: 0.4608 - val_accuracy: 0.8112 - lr: 0.0010
# Epoch 26/100
# 18/18 [==============================] - 0s 5ms/step - loss: 0.5231 - accuracy: 0.7768 - val_loss: 0.4597 - val_accuracy: 0.7972 - lr: 0.0010
# Epoch 27/100
# 18/18 [==============================] - 0s 5ms/step - loss: 0.5299 - accuracy: 0.7750 - val_loss: 0.4453 - val_accuracy: 0.8322 - lr: 0.0010
# Epoch 28/100
# 18/18 [==============================] - 0s 5ms/step - loss: 0.4960 - accuracy: 0.7838 - val_loss: 0.4466 - val_accuracy: 0.8322 - lr: 0.0010
# Epoch 29/100
# 18/18 [==============================] - 0s 5ms/step - loss: 0.5027 - accuracy: 0.7698 - val_loss: 0.4433 - val_accuracy: 0.8322 - lr: 0.0010
# Epoch 30/100
# 18/18 [==============================] - 0s 5ms/step - loss: 0.4978 - accuracy: 0.7891 - val_loss: 0.4485 - val_accuracy: 0.8112 - lr: 0.0010
# Epoch 31/100
# 18/18 [==============================] - 0s 5ms/step - loss: 0.5183 - accuracy: 0.7715 - val_loss: 0.4473 - val_accuracy: 0.8112 - lr: 0.0010
# Epoch 32/100
# 18/18 [==============================] - 0s 5ms/step - loss: 0.5265 - accuracy: 0.7715 - val_loss: 0.4596 - val_accuracy: 0.7902 - lr: 0.0010
# Epoch 33/100
# 18/18 [==============================] - 0s 5ms/step - loss: 0.5401 - accuracy: 0.7557 - val_loss: 0.4563 - val_accuracy: 0.8112 - lr: 0.0010
# Epoch 34/100
# 18/18 [==============================] - 0s 5ms/step - loss: 0.4959 - accuracy: 0.7821 - val_loss: 0.4433 - val_accuracy: 0.8322 - lr: 0.0010
# Epoch 35/100
# 18/18 [==============================] - 0s 5ms/step - loss: 0.4823 - accuracy: 0.7944 - val_loss: 0.4489 - val_accuracy: 0.8182 - lr: 0.0010
# Epoch 36/100
# 18/18 [==============================] - 0s 5ms/step - loss: 0.5081 - accuracy: 0.7663 - val_loss: 0.4462 - val_accuracy: 0.8042 - lr: 0.0010
# Epoch 37/100
# 18/18 [==============================] - 0s 5ms/step - loss: 0.5075 - accuracy: 0.7891 - val_loss: 0.4485 - val_accuracy: 0.8112 - lr: 0.0010
# Epoch 38/100
# 18/18 [==============================] - 0s 6ms/step - loss: 0.5010 - accuracy: 0.7750 - val_loss: 0.4426 - val_accuracy: 0.8112 - lr: 0.0010
# Epoch 39/100
# 18/18 [==============================] - 0s 6ms/step - loss: 0.5108 - accuracy: 0.7663 - val_loss: 0.4435 - val_accuracy: 0.8252 - lr: 0.0010
# Epoch 40/100
# 18/18 [==============================] - 0s 6ms/step - loss: 0.5094 - accuracy: 0.7663 - val_loss: 0.4442 - val_accuracy: 0.8322 - lr: 0.0010
# Epoch 41/100
# 18/18 [==============================] - 0s 6ms/step - loss: 0.5097 - accuracy: 0.7838 - val_loss: 0.4467 - val_accuracy: 0.8322 - lr: 0.0010
# Epoch 42/100
# 18/18 [==============================] - 0s 6ms/step - loss: 0.5089 - accuracy: 0.7838 - val_loss: 0.4453 - val_accuracy: 0.8322 - lr: 0.0010
# Epoch 43/100
# 18/18 [==============================] - 0s 6ms/step - loss: 0.4949 - accuracy: 0.7733 - val_loss: 0.4372 - val_accuracy: 0.8322 - lr: 0.0010
# Epoch 44/100
# 18/18 [==============================] - 0s 6ms/step - loss: 0.5092 - accuracy: 0.7750 - val_loss: 0.4437 - val_accuracy: 0.8252 - lr: 0.0010
# Epoch 45/100
# 18/18 [==============================] - 0s 6ms/step - loss: 0.4937 - accuracy: 0.7891 - val_loss: 0.4396 - val_accuracy: 0.8252 - lr: 0.0010
# Epoch 46/100
# 18/18 [==============================] - 0s 6ms/step - loss: 0.5080 - accuracy: 0.7733 - val_loss: 0.4392 - val_accuracy: 0.8252 - lr: 0.0010
# Epoch 47/100
# 18/18 [==============================] - 0s 6ms/step - loss: 0.4971 - accuracy: 0.7856 - val_loss: 0.4390 - val_accuracy: 0.8252 - lr: 0.0010
# Epoch 48/100
# 18/18 [==============================] - 0s 6ms/step - loss: 0.4935 - accuracy: 0.7786 - val_loss: 0.4400 - val_accuracy: 0.8112 - lr: 0.0010
# Epoch 49/100
# 18/18 [==============================] - 0s 6ms/step - loss: 0.5027 - accuracy: 0.7856 - val_loss: 0.4355 - val_accuracy: 0.8322 - lr: 0.0010
# Epoch 50/100
# 18/18 [==============================] - 0s 5ms/step - loss: 0.4887 - accuracy: 0.7715 - val_loss: 0.4395 - val_accuracy: 0.8182 - lr: 0.0010
# Epoch 51/100
# 18/18 [==============================] - 0s 5ms/step - loss: 0.4908 - accuracy: 0.7821 - val_loss: 0.4370 - val_accuracy: 0.8182 - lr: 0.0010
# Epoch 52/100
# 18/18 [==============================] - 0s 6ms/step - loss: 0.4954 - accuracy: 0.7838 - val_loss: 0.4356 - val_accuracy: 0.8252 - lr: 0.0010
# Epoch 53/100
# 18/18 [==============================] - 0s 6ms/step - loss: 0.4846 - accuracy: 0.7891 - val_loss: 0.4435 - val_accuracy: 0.8112 - lr: 0.0010
# Epoch 54/100
# 18/18 [==============================] - 0s 7ms/step - loss: 0.5030 - accuracy: 0.7750 - val_loss: 0.4380 - val_accuracy: 0.8182 - lr: 0.0010
# Epoch 55/100
# 18/18 [==============================] - 0s 5ms/step - loss: 0.4971 - accuracy: 0.7891 - val_loss: 0.4326 - val_accuracy: 0.8252 - lr: 0.0010
# Epoch 56/100
# 18/18 [==============================] - 0s 5ms/step - loss: 0.4815 - accuracy: 0.7856 - val_loss: 0.4311 - val_accuracy: 0.8252 - lr: 0.0010
# Epoch 57/100
# 18/18 [==============================] - 0s 5ms/step - loss: 0.4923 - accuracy: 0.7891 - val_loss: 0.4421 - val_accuracy: 0.8112 - lr: 0.0010
# Epoch 58/100
# 18/18 [==============================] - 0s 5ms/step - loss: 0.4728 - accuracy: 0.7944 - val_loss: 0.4353 - val_accuracy: 0.8322 - lr: 0.0010
# Epoch 59/100
# 18/18 [==============================] - 0s 5ms/step - loss: 0.4811 - accuracy: 0.7873 - val_loss: 0.4302 - val_accuracy: 0.8322 - lr: 0.0010
# Epoch 60/100
# 18/18 [==============================] - 0s 5ms/step - loss: 0.4717 - accuracy: 0.8120 - val_loss: 0.4309 - val_accuracy: 0.8322 - lr: 0.0010
# Epoch 61/100
# 18/18 [==============================] - 0s 5ms/step - loss: 0.4861 - accuracy: 0.7961 - val_loss: 0.4289 - val_accuracy: 0.8182 - lr: 0.0010
# Epoch 62/100
# 18/18 [==============================] - 0s 5ms/step - loss: 0.4770 - accuracy: 0.7838 - val_loss: 0.4253 - val_accuracy: 0.8252 - lr: 0.0010
# Epoch 63/100
# 18/18 [==============================] - 0s 5ms/step - loss: 0.4753 - accuracy: 0.7996 - val_loss: 0.4338 - val_accuracy: 0.8112 - lr: 0.0010
# Epoch 64/100
# 18/18 [==============================] - 0s 5ms/step - loss: 0.4530 - accuracy: 0.8032 - val_loss: 0.4363 - val_accuracy: 0.8112 - lr: 0.0010
# Epoch 65/100
# 18/18 [==============================] - 0s 5ms/step - loss: 0.4798 - accuracy: 0.8014 - val_loss: 0.4277 - val_accuracy: 0.8252 - lr: 0.0010
# Epoch 66/100
# 18/18 [==============================] - 0s 5ms/step - loss: 0.4849 - accuracy: 0.7733 - val_loss: 0.4289 - val_accuracy: 0.8252 - lr: 0.0010
# Epoch 67/100
# 18/18 [==============================] - 0s 5ms/step - loss: 0.4845 - accuracy: 0.7821 - val_loss: 0.4316 - val_accuracy: 0.8252 - lr: 0.0010
# Epoch 68/100
# 18/18 [==============================] - 0s 5ms/step - loss: 0.4752 - accuracy: 0.7698 - val_loss: 0.4302 - val_accuracy: 0.8252 - lr: 0.0010
# Epoch 69/100
# 18/18 [==============================] - 0s 5ms/step - loss: 0.4852 - accuracy: 0.7821 - val_loss: 0.4300 - val_accuracy: 0.8252 - lr: 0.0010
# Epoch 70/100
# 18/18 [==============================] - 0s 5ms/step - loss: 0.4717 - accuracy: 0.8067 - val_loss: 0.4230 - val_accuracy: 0.8322 - lr: 0.0010
# Epoch 71/100
# 18/18 [==============================] - 0s 5ms/step - loss: 0.5058 - accuracy: 0.7715 - val_loss: 0.4330 - val_accuracy: 0.8322 - lr: 0.0010
# Epoch 72/100
# 18/18 [==============================] - 0s 5ms/step - loss: 0.4736 - accuracy: 0.7944 - val_loss: 0.4258 - val_accuracy: 0.8322 - lr: 0.0010
# Epoch 73/100
# 18/18 [==============================] - 0s 5ms/step - loss: 0.4817 - accuracy: 0.7750 - val_loss: 0.4254 - val_accuracy: 0.8252 - lr: 0.0010
# Epoch 74/100
# 18/18 [==============================] - 0s 9ms/step - loss: 0.4778 - accuracy: 0.7750 - val_loss: 0.4273 - val_accuracy: 0.8252 - lr: 0.0010
# Epoch 75/100
# 18/18 [==============================] - 0s 5ms/step - loss: 0.4825 - accuracy: 0.7838 - val_loss: 0.4235 - val_accuracy: 0.8322 - lr: 0.0010
# Epoch 76/100
# 18/18 [==============================] - 0s 5ms/step - loss: 0.4950 - accuracy: 0.7873 - val_loss: 0.4304 - val_accuracy: 0.8252 - lr: 0.0010
# Epoch 77/100
# 18/18 [==============================] - 0s 5ms/step - loss: 0.4762 - accuracy: 0.7856 - val_loss: 0.4299 - val_accuracy: 0.8252 - lr: 0.0010
# Epoch 78/100
# 18/18 [==============================] - 0s 5ms/step - loss: 0.4813 - accuracy: 0.7944 - val_loss: 0.4229 - val_accuracy: 0.8252 - lr: 0.0010
# Epoch 79/100
# 18/18 [==============================] - 0s 5ms/step - loss: 0.4740 - accuracy: 0.7856 - val_loss: 0.4260 - val_accuracy: 0.8252 - lr: 0.0010
# Epoch 80/100
# 18/18 [==============================] - 0s 5ms/step - loss: 0.4803 - accuracy: 0.7803 - val_loss: 0.4310 - val_accuracy: 0.8252 - lr: 0.0010
# Epoch 81/100
# 18/18 [==============================] - 0s 5ms/step - loss: 0.4590 - accuracy: 0.8032 - val_loss: 0.4267 - val_accuracy: 0.8322 - lr: 0.0010
# Epoch 82/100
# 18/18 [==============================] - 0s 5ms/step - loss: 0.4801 - accuracy: 0.7926 - val_loss: 0.4291 - val_accuracy: 0.8252 - lr: 0.0010
# Epoch 83/100
# 18/18 [==============================] - 0s 5ms/step - loss: 0.4759 - accuracy: 0.7909 - val_loss: 0.4361 - val_accuracy: 0.8322 - lr: 0.0010
# Epoch 84/100
# 18/18 [==============================] - 0s 5ms/step - loss: 0.4755 - accuracy: 0.7873 - val_loss: 0.4296 - val_accuracy: 0.8252 - lr: 0.0010
# Epoch 85/100
# 18/18 [==============================] - 0s 5ms/step - loss: 0.4754 - accuracy: 0.7856 - val_loss: 0.4239 - val_accuracy: 0.8252 - lr: 0.0010
# Epoch 86/100
# 18/18 [==============================] - 0s 5ms/step - loss: 0.4642 - accuracy: 0.7926 - val_loss: 0.4243 - val_accuracy: 0.8322 - lr: 0.0010
# Epoch 87/100
# 18/18 [==============================] - 0s 5ms/step - loss: 0.4673 - accuracy: 0.8084 - val_loss: 0.4273 - val_accuracy: 0.8322 - lr: 0.0010
# Epoch 88/100
# 18/18 [==============================] - 0s 7ms/step - loss: 0.4863 - accuracy: 0.7821 - val_loss: 0.4303 - val_accuracy: 0.8252 - lr: 0.0010
# Epoch 89/100
# 18/18 [==============================] - 0s 5ms/step - loss: 0.4602 - accuracy: 0.7979 - val_loss: 0.4294 - val_accuracy: 0.8252 - lr: 1.0000e-04
# Epoch 90/100
# 18/18 [==============================] - 0s 5ms/step - loss: 0.4676 - accuracy: 0.7961 - val_loss: 0.4294 - val_accuracy: 0.8252 - lr: 1.0000e-04
# Epoch 91/100
# 18/18 [==============================] - 0s 5ms/step - loss: 0.4594 - accuracy: 0.8049 - val_loss: 0.4284 - val_accuracy: 0.8252 - lr: 1.0000e-04
# Epoch 92/100
# 18/18 [==============================] - 0s 5ms/step - loss: 0.4624 - accuracy: 0.7944 - val_loss: 0.4279 - val_accuracy: 0.8252 - lr: 1.0000e-04
# Epoch 93/100
# 18/18 [==============================] - 0s 5ms/step - loss: 0.4668 - accuracy: 0.7996 - val_loss: 0.4277 - val_accuracy: 0.8252 - lr: 1.0000e-04
# Epoch 94/100
# 18/18 [==============================] - 0s 5ms/step - loss: 0.4782 - accuracy: 0.7891 - val_loss: 0.4272 - val_accuracy: 0.8252 - lr: 1.0000e-04
# Epoch 95/100
# 18/18 [==============================] - 0s 5ms/step - loss: 0.4655 - accuracy: 0.8049 - val_loss: 0.4274 - val_accuracy: 0.8252 - lr: 1.0000e-04
# Epoch 96/100
# 18/18 [==============================] - 0s 5ms/step - loss: 0.4748 - accuracy: 0.7944 - val_loss: 0.4271 - val_accuracy: 0.8252 - lr: 1.0000e-04
# Epoch 97/100
# 18/18 [==============================] - 0s 5ms/step - loss: 0.4646 - accuracy: 0.7926 - val_loss: 0.4275 - val_accuracy: 0.8252 - lr: 1.0000e-04
# Epoch 98/100
# 18/18 [==============================] - 0s 6ms/step - loss: 0.4706 - accuracy: 0.7979 - val_loss: 0.4272 - val_accuracy: 0.8252 - lr: 1.0000e-04

# %% [markdown]
# # Evaluation

# %%
# Plot training history
plt.plot(history.history['loss'], label='Training Loss')
plt.plot(history.history['val_loss'], label='Validation Loss')
plt.title('Training and Validation Loss')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.legend()
plt.show()

plt.plot(history.history['accuracy'], label='Training Accuracy')
plt.plot(history.history['val_accuracy'], label='Validation Accuracy')
plt.title('Training and Validation Accuracy')
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.legend()
plt.show()

# %%
y_pred = model.predict(X_val)
y_pred = (y_pred >= 0.5).astype(int)

cm = confusion_matrix(y_val, y_pred)
disp = ConfusionMatrixDisplay(confusion_matrix=cm, display_labels=[0, 1])
disp.plot(cmap=plt.cm.Reds)
plt.title('Confusion Matrix')
plt.show()
# Out:
# 6/6 [==============================] - 0s 2ms/step

# %% [markdown]
# # Create Submission

# %%
test_set_cleaned = test_set[["Pclass", "Sex", "Age", "SibSp", "Parch", "Ticket", "Fare", "Cabin", "Embarked"]]
test_set_cleaned = test_set_cleaned.fillna(0)
test_set_cleaned["Cabin"] = test_set_cleaned["Cabin"].astype(str)
test_set_cleaned["Embarked"] = test_set_cleaned["Embarked"].astype(str)
for column in test_set_cleaned.columns:
    encoder = LabelEncoder()
    test_set_cleaned[column] = encoder.fit_transform(test_set_cleaned[column])
for column in test_set_cleaned.columns:
    scaler = MinMaxScaler()
    reshaped_column = np.array(test_set_cleaned[column]).reshape(-1, 1)
    test_set_cleaned[column] = scaler.fit_transform(reshaped_column)

# %%
predictions = model.predict(test_set_cleaned)
predictions = (predictions >= 0.5).astype(int)
predictions = np.squeeze(predictions)

output = pd.DataFrame({'PassengerId': test_set["PassengerId"], 'Survived': predictions})
output.to_csv('./Data/submission.csv', index=False)
# Out:
# 14/14 [==============================] - 0s 2ms/step
